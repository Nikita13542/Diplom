# %%
import os

os.environ["ROVER_IP"] = "192.168.4.1"
os.environ["PHONE_IP"] = "192.168.4.2"
os.environ["CAMERA_MODE"] = "IP_WEBCAM"
os.environ["TARGET_COLOR"] = "GREEN"

from secure_rover_autopilot import run_autopilot
run_autopilot()
